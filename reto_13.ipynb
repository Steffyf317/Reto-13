# %%
# Desarrollar un algoritmo que imprima de manera ascendente los valores (todos del mismo tipo) de un diccionario.
def imprimir_valores_ascendentes(diccionario:dict):
  valores_diccionario = list(diccionario.values()) #volver lista los valores del diccionario
  valores_diccionario.sort() #ordenar los valores
  for i in valores_diccionario:
    print(i)
  return

if __name__== "__main__":
  diccionario = {"veintiuno":"u", "nueve":"i", "cinco":"e", "uno": "a", "quince":"o"} #diccionario con el número de la posición en el alfabeto de cada vocal 
  valores_organizados_ascendente = imprimir_valores_ascendentes(diccionario)
# Out:
# a
# e
# i
# o
# u

# %%
# Desarrollar una funcion que reciba dos diccionarios como parametros y los mezcle, es decir, que se construya un nuevo diccionario con las llaves de los dos diccionarios; si hay una clave repetida en ambos diccionarios, se debe asignar el valor que tenga la clave en el primer diccionario.
def mezclar_diccionarios(dic_1:dict,dic_2:dict):
  copia_diccionario_1 = dic_1.copy() # hacer una copia del diccionario 1
  diccionario_mezclado = copia_diccionario_1 

  for i,j in dic_2.items(): # key, value respectivamente
    if i not in dic_1:
      diccionario_mezclado[i]=j # se asigna el valor j a la llave respectiva (i)
  return diccionario_mezclado

if __name__== "__main__":
  dic_1 = {"veintiuno":"u", "nueve":"i", "cinco":"e", "uno": "a", "quince":"o"} #diccionario con el número de la posición en el alfabeto de cada vocal
  dic_2 = {"dos":"b","seis":"f","diecinueve":"s","dieciocho":"r","cinco":"e"} #diccionario con el número de la posición en el alfabeto de cada letra
  mezcla_diccionarios = mezclar_diccionarios(dic_1,dic_2)
  print(mezcla_diccionarios)
# Out:
# {'veintiuno': 'u', 'nueve': 'i', 'cinco': 'e', 'uno': 'a', 'quince': 'o', 'dos': 'b', 'seis': 'f', 'diecinueve': 's', 'dieciocho': 'r'}

# %%
# Cree un programa que lea de un archivo con dicho JSON y:
#Imprima los nombres completos (nombre y apellidos) de las personas que practican el deporte ingresado por el usuario.
#Imprima los nombres completos (nombre y apellidos) de las personas que est�en en un rango de edades dado por el usuario.

import json

def evaluar_deporte(data,deporte):
  nombres_completos = [] #crear una lista para guardar los nombres completos que cumplen el condicional
  for k,v in data.items(): #key, value respectivamente
    if deporte in v["deportes"]: #si el deporte ingresado por el usuario está dentro de los valores de la clave "deportes":
      nombres_completos.append((v["nombres"], v["apellidos"])) #agregar a la lista vacía lo que cumple el condicional 

  if nombres_completos:
    return nombres_completos
  else:
    return "No se encontraron personas que practiquen el deporte"       

def evaluar_rangos_edad(data, edad_maxima,edad_minima):
  nombres_completos = [] #crear una lista para guardar los nombres completos que cumplen el condicional
  for k,v in data.items():
    if edad_minima <= v["edad"] <= edad_maxima: #si la edad está dentro del rango de valores del archivo json:
      nombres_completos.append((v["nombres"], v["apellidos"])) #agregar a la lista vacía lo que cumple el condicional
      
  if nombres_completos:
    return nombres_completos
  else:
    return "No se encontraron personas que tengan los años dentro del rango."

if __name__ == "__main__":
  #cargar archivo json
  archivo_json = r"C:\Users\stfer\OneDrive\Escritorio\UNAL IQ\VIII SEMESTRE\PROGRAMACIÓN DE COMPUTADORES\archivo_reto_13.json"
  with open(archivo_json, "r", encoding="utf-8") as readFile:
    data = json.load(readFile)
  
  deporte = input("Ingrese el nombre de un deporte ")
  edad_minima = int(input("Ingrese la edad mínima del rango "))
  edad_maxima = int(input("Ingrese la edad máxima del rango "))


  deporte_respectivo = evaluar_deporte(data,deporte)
10d\", \"2\": \"10d\", \"3\": \"10d\", \"4\": \"10d\", \"5\": \"10d\", \"6\": \"10d\", \"7\": \"10d\"}, \"alertPrecip\": {\"0\": \"X\", \"1\": \"-\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"alertAlertas\": {\"0\": \"-\", \"1\": \"-\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"alertVelViento\": {\"0\": \"-\", \"1\": \"-\", \"2\": \"X\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"alertTmpMax\": {\"0\": \"-\", \"1\": \"-\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"X\", \"6\": \"-\", \"7\": \"-\"}, \"alertTmpMin\": {\"0\": \"-\", \"1\": \"X\", \"2\": \"-\", \"3\": \"-\", \"4\": \"-\", \"5\": \"-\", \"6\": \"-\", \"7\": \"-\"}, \"recomendaciones\": {\"lluvias\": \"Realice una revisi\\u00f3n y limpieza a la red de desague y canales existentes ENTER8 Cuente con una estaci\\u00f3n de bombeo, que debe estar ubicada en el punto m\\u00e1s bajo del predio. Aseg\\u00farese de encender y probar el sistema de bombeo al menos una vez al mes y hacer un mantenimiento mensual al equipo de bombeoENTER8 Los productos alojados en zonas de almacenamiento deben mantenersen sobre estibas - estanterias, con el fin de que no entren en contacto directo con el agua.\", \"vientos\": \"-\", \"temperatura\": \"-\"}}
'''
data = json.loads(jsonString) #cargar el string json a un diccionario de python

# Función para convertir UNIX a fecha legible
def unix_a_fecha(unix_time):
  return datetime.utcfromtimestamp(unix_time).strftime('%Y-%m-%d')

# Función para identificar alertas y asociar detalles climáticos
def revisar_alertas(data):
    # Diccionario de campos de alerta y los parámetros relevantes a extraer
  alertas = {
    'alertPrecip': 'prcp',
    'alertVelViento': 'velViento',
    'alertTmpMax': 'tmpMax',
    'alertTmpMin': 'tmpMin',
  }
    
    # Iterar por cada alerta definida en el diccionario
  for alerta, parametro in alertas.items(): #respectivamente llave,valor
      print(f"\nRevisando alerta: {alerta}")
      hay_alerta = False  #Bandera para determinar si hay alguna alerta en los datos
        
      for dia in range(8): #rango de 8 dias, donde se reportan los datos
        if data[alerta][str(dia)] == "X":  # Si hay una alerta marcada con x
          hay_alerta = True #Se activa la bandera indicando que hay una alerta
          fecha = unix_a_fecha(data["dt"][str(dia)]) # Obtener fecha de UNIX a formato legible
          valor_parametro = data[parametro][str(dia)] # Obtener el valor del parámetro asociado
                
          # Mostrar alerta y detalles
          print(f"Alerta en fecha: {fecha}")
          print(f"Tipo de alerta: {alerta}")
          print(f"Valor asociado: {parametro} = {valor_parametro}")
        
      if not hay_alerta: # Si no hay ninguna alerta para ese campo, no imprime nada
        print(f"Sin alertas para {alerta}")

if __name__ == "__main__":
  revisar_alertas(data)
# Out:
# Revisando alerta: alertPrecip
# Alerta en fecha: 2023-05-26
# Tipo de alerta: alertPrecip
# Valor asociado: prcp = 40.0
#
# Revisando alerta: alertVelViento
# Alerta en fecha: 2023-05-28
# Tipo de alerta: alertVelViento
# Valor asociado: velViento = 5.38
#
# Revisando alerta: alertTmpMax
# Alerta en fecha: 2023-05-31
# Tipo de alerta: alertTmpMax
# Valor asociado: tmpMax = 29.78
#
# Revisando alerta: alertTmpMin
# Alerta en fecha: 2023-05-27
# Tipo de alerta: alertTmpMin
# Valor asociado: tmpMin = 24.64

# %%
# !pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 24.2
# [notice] To update, run: C:\Users\stfer\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import json
import requests #previamente se instaló en la casilla anterior 

# Función para obtener datos de PokeAPI
def buscar_pokemon_num(num:int):
  url = 'https://pokeapi.co/api/v2/pokemon/'
  peticion = requests.get(url + str(num)) # Realizamos la solicitud a la API, concatenando el número del Pokémon al final de la url
  print("Estado de la petición PokeAPI: {peticion.status_code}")

  if peticion.status_code == 200: #si la petición es exitosa, hacer:
    return peticion.json()
  else:
    return None

# Función para obtener datos de JSONPlaceholder
def buscar_usuario(id:int):
  url = 'https://jsonplaceholder.typicode.com/users/'
  peticion = requests.get(url + str(id)) # Realizamos la solicitud a la API, concatenando el número la id del usuario a la url 
  print(f"Estado de la petición JSONPlaceholder: {peticion.status_code}")

  if peticion.status_code == 200:
    return peticion.json()
  else:
    return None

# Función para obtener datos de JSONPlaceholder (posts)
def buscar_post(id: int):
  url = 'https://jsonplaceholder.typicode.com/posts/'
  peticion = requests.get(url + str(id)) # Realizamos la solicitud, añadiendo el ID del post a la URL
  print(f"Estado de la petición JSONPlaceholder (posts): {peticion.status_code}")

  if peticion.status_code == 200:
    return peticion.json()
  else:
    return None

if __name__ == "__main__":
  # Obtener datos de PokeAPI
  pokemon_respuesta = buscar_pokemon_num(1) #obtener datos de PokeAPI para el Pokémon con ID 1 (Bulbasaur)
  if pokemon_respuesta:
    print("\nDatos de PokeAPI:")
    print(json.dumps(pokemon_respuesta, indent=2)) #datos formateados en formato JSON
    print("\nPares de llave: valor:")
    for key, value in pokemon_respuesta.items(): #pares clave:valor
      print(f"{key}: {value}") 

    # Obtener datos de JSONPlaceholder
    usuario_respuesta = buscar_usuario(1) #obtener datos de JSONPlaceholder para el usuario con ID 1
  if usuario_respuesta:
    print("\nDatos de JSONPlaceholder:")
    print(json.dumps(usuario_respuesta, indent=2)) # Mostramos los datos formateados en formato JSON
    print("\nPares de llave: valor:")
    for key, value in usuario_respuesta.items():
      print(f"{key}: {value}")

  post_respuesta = buscar_post(1)
  if post_respuesta: # Si la respuesta es válida, imprimimos los datos
    print("\nDatos de JSONPlaceholder (post):")
    print(json.dumps(post_respuesta, indent=2)) # Mostramos los datos formateados en formato JSON
    print("\nPares de llave: valor:") # Imprimimos pares clave-valor del JSON
    for key, value in post_respuesta.items():
      print(f"{key}: {value}")
# Out:
# Estado de la petición PokeAPI: {peticion.status_code}
#
# Datos de PokeAPI:
# {
#   "abilities": [
#     {
#       "ability": {
#         "name": "overgrow",
#         "url": "https://pokeapi.co/api/v2/ability/65/"
#       },
#       "is_hidden": false,
#       "slot": 1
#     },
#     {
#       "ability": {
#         "name": "chlorophyll",
#         "url": "https://pokeapi.co/api/v2/ability/34/"
#       },
#       "is_hidden": true,
#       "slot": 3
#     }
#   ],
#   "base_experience": 64,
#   "cries": {
#     "latest": "https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/latest/1.ogg",
#     "legacy": "https://raw.githubusercontent.com/PokeAPI/cries/main/cries/pokemon/legacy/1.ogg"
#   },
#   "forms": [
#     {
#       "name": "bulbasaur",
#       "url": "https://pokeapi.co/api/v2/pokemon-form/1/"
#     }
#   ],
#   "game_indices": [
#     {
#       "game_index": 153,
#       "version": {
#         "name": "red",
# ...
